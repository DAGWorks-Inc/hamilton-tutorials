# %% [markdown]
# # Notebook setup

# %%
from IPython.display import clear_output

# %% [markdown]
# Uncomment and run the cell below if you are in a Google Colab environment. It will clone this repository on the Google Colab runtime cloud disk, move your current directory, and install requirements.

# %%
# !git clone https://github.com/DAGWorks-Inc/hamilton-tutorials/
# %cd hamilton-tutorials/2023-08-08
# %pip install -r requirements.txt
# clear_output()

# %% [markdown]
# # Imports

# %%
import inspect

import numpy as np
import pandas as pd
from hamilton import driver
from IPython.display import display

import data_cleaning
import features

# Use autoreload to automatically reload our function modules
# %load_ext autoreload
# %autoreload 1
# %aimport data_cleaning, features
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Hamilton Driver

# %%
driver_config = {}
dr = driver.Driver(
    driver_config,
    data_cleaning,
)

requested_outputs = [
    "application_clean"
]

inputs = dict(
)

results = dr.execute(requested_outputs, inputs=inputs)

display(
    dr.visualize_execution(requested_outputs, None, inputs),
    results.head(),
)
# Out:
#          cnt_children  amt_income_total  days_birth  days_employed  \
# ID
# 5008804             0          427500.0      -12005          -4542
# 5008805             0          427500.0      -12005          -4542
# 5008806             0          112500.0      -21474          -1134
# 5008808             0          270000.0      -19110          -3051
# 5008809             0          270000.0      -19110          -3051
#
#          flag_mobil  flag_work_phone  flag_phone  flag_email  cnt_fam_members  \
# ID
# 5008804           1                1           0           0              2.0
# 5008805           1                1           0           0              2.0
# 5008806           1                0           0           0              2.0
# 5008808           1                0           1           1              1.0
# 5008809           1                0           1           1              1.0
#
#          eduction_type_encoded  family_status_encoded  gender_encoded  \
# ID
# ...
